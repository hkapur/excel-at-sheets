# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# Initialize the OpenAI client
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# Make a simple call to the OpenAI API
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Hello, can you tell me about data analysis?"}
    ],
    temperature=0.7,
)

# Print the response
print("Response from OpenAI:")
print(response.choices[0].message.content)
# Out:
# Response from OpenAI:
# Certainly! Data analysis is the process of inspecting, cleaning, transforming, and modeling data with the goal of discovering useful information, drawing conclusions, and supporting decision-making. It involves various techniques and methodologies, depending on the type of data and the objectives of the analysis.
#
# Here are some key aspects of data analysis:
#
# ### 1. **Types of Data Analysis**
#    - **Descriptive Analysis**: Summarizes the main characteristics of a dataset, often using statistical measures such as mean, median, mode, and standard deviation. It helps in understanding past trends and patterns.
#    - **Exploratory Analysis**: Involves exploring data sets to find patterns, anomalies, or relationships without having a specific hypothesis in mind. Techniques include data visualization and clustering.
#    - **Inferential Analysis**: Makes inferences about a population based on sample data. It often involves hypothesis testing, confidence intervals, and regression analysis.
#    - **Predictive Analysis**: Uses historical data to make predictions about future outcomes. Techniques include machine learning algorithms, time series analysis, and regression models.
#    - **Prescriptive Analysis**: Suggests actions based on data analysis. It often uses optimization and simulation techniques to recommend decisions.
#
# ### 2. **Data Collection**
# Data can be collected from various sources, including:
#    - Surveys and questionnaires
#    - Experiments
#    - Transactional data from databases
#    - Web scraping
#    - Public datasets
#
# ### 3. **Data Cleaning and Preparation**
# Before analysis, data often requires cleaning and preparation, which can include:
#    - Handling missing values
#    - Removing duplicates
#    - Correcting inconsistencies
#    - Normalizing data formats
#    - Transforming variables (e.g., log transformations)
#
# ### 4. **Data Visualization**
# Visualizing data is crucial for understanding and communicating insights. Common techniques include:
#    - Charts (bar charts, line graphs, pie charts)
#    - Histograms
#    - Scatter plots
#    - Heatmaps
#    - Dashboards
#
# ### 5. **Statistical Techniques**
# Data analysis often employs various statistical techniques, including:
#    - Regression analysis (linear and logistic)
#    - ANOVA (Analysis of Variance)
#    - Chi-square tests
#    - Time series analysis
#
# ### 6. **Software and Tools**
# There are numerous tools and programming languages used for data analysis, including:
#    - **Excel**: For basic data manipulation and analysis.
#    - **R**: A programming language designed for statistical analysis and visualization.
#    - **Python**: Widely used for data analysis, with libraries like Pandas, NumPy, and Matplotlib.
#    - **SQL**: For querying and managing data in relational databases.
#    - **Tableau** and **Power BI**: For creating interactive visualizations and dashboards.
#
# ### 7. **Applications of Data Analysis**
# Data analysis is applied across various fields, including:
#    - Business (market research, sales forecasting)
#    - Healthcare (patient data analysis, clinical trials)
#    - Finance (risk assessment, fraud detection)
#    - Social sciences (survey analysis, behavioral studies)
#    - Marketing (customer segmentation, campaign effectiveness)
#
# ### Conclusion
# Data analysis is an essential skill in today’s data-driven world. It enables organizations to make informed decisions based on empirical evidence, leading to better outcomes and strategic advantages. If you have specific questions or need more details about any aspect of data analysis, feel free to ask!
